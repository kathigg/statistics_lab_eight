# %%
import random
x= random.uniform(0, 1)
print(x)
# Out:
# 0.2373080220660354

# %%
import numpy as np
import matplotlib.pyplot as plt
n = 150000

a = np.random.uniform(0, 1, n)

# Histogram
hist, bins = np.histogram(a, bins = 20)
plt.bar(bins[:-1], hist, width = np.diff(bins), edgecolor = "black")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram")
plt.show()

# %%
# Example 2

u = random.uniform(0, 1)
if u < 0.5:
  a = "Head"
else:
  a = "Tail"
print(a)
# Out:
# Head

# %%
# Exercise 1
n = 10000
d = [0] * n # a dummy array of zeroes, of length 10000

for i in range(n):
  u = random.uniform(0, 1)
  if u < 0.6:
    d[i] = "Head"
  else:
    d[i] = "Tail"
print(d)
# Out:
# ['Tail', 'Tail', 'Tail', 'Head', 'Tail', 'Tail', 'Head', 'Tail', 'Tail', 'Head', 'Tail', 'Head', 'Tail', 'Head', 'Tail', 'Tail', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Tail', 'Tail', 'Head', 'Tail', 'Head', 'Head', 'Tail', 'Head', 'Tail', 'Head', 'Head', 'Tail', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Tail', 'Tail', 'Head', 'Tail', 'Head', 'Head', 'Tail', 'Tail', 'Head', 'Head', 'Tail', 'Head', 'Tail', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Tail', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Tail', 'Head', 'Tail', 'Tail', 'Tail', 'Tail', 'Tail', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Tail', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Tail', 'Head', 'Tail', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Tail', 'Tail', 'Head', 'Tail', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Tail', 'Tail', 'Tail', 'Tail', 'Head', 'Head', 'Head', 'Tail', 'Tail', 'Head', 'Head', 'Tail', 'Tail', 'Head', 'Tail', 'Tail', 'Head', 'Tail', 'Tail', 'Tail', 'Tail', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Tail', 'Tail', 'Tail', 'Tail', 'Head', 'Head', 'Head', 'Tail', 'Tail', 'Head', 'Head', 'Tail', 'Tail', 'Tail', 'Tail', 'Tail', 'Tail', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Tail', 'Head', 'Tail', 'Tail', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Tail', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Tail', 'Tail', 'Head', 'Tail', 'Head', 'Head', 'Tail', 'Tail', 'Tail', 'Head', 'Head', 'Tail', 'Head', 'Tail', 'Head', 'Tail', 'Tail', 'Tail', 'Tail', 'Tail', 'Head', 'Head', 'Tail', 'Head', 'Tail', 'Head', 'Tail', 'Tail', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Tail', 'Head', 'Head', 'Tail', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Tail', 'Tail', 'Tail', 'Tail', 'Tail', 'Head', 'Tail', 'Tail', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Tail', 'Tail', 'Head', 'Head', 'Head', 'Tail', 'Tail', 'Tail', 'Head', 'Tail', 'Head', 'Head', 'Tail', 'Tail', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Tail', 'Tail', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Tail', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Tail', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Tail', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Tail', 'Tail', 'Tail', 'Head', 'Tail', 'Head', 'Tail', 'Head', 'Tail', 'Head', 'Tail', 'Head', 'Tail', 'Tail', 'Tail', 'Tail', 'Tail', 'Head', 'Tail', 'Head', 'Head', 'Tail', 'Tail', 'Tail', 'Head', 'Head', 'Tail', 'Head', 'Tail', 'Head', 'Head', 'Tail', 'Head', 'Tail', 'Head', 'Tail', 'Tail', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Tail', 'Tail', 'Tail', 'Tail', 'Tail', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Tail', 'Tail', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Tail', 'Head', 'Head', 'Tail', 'Head', 'Tail', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Head', 'Head', 'Tail', 'Head', 'Head', 'Head', 'Tail', 'Head', ...

# %%
# Bar chart
'''
Suppose we have a biased coin which turns head 60% of the time. Simulate 10,000 tosses of this
coin and make a bar plot of the outcomes.
'''

import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame(d)
df.value_counts().plot(kind = "bar")
plt.xlabel("Outcome")
plt.ylabel("Frequency")
plt.title("Bar Chart")
plt.show()

# %%
# Simulate a Random Walk

u = random.uniform(0, 1)
if (u < 0.2):
  f = "up"
elif u >= 0.2 and u < 0.5:
  f = "down"
elif u >= 0.5 and u < 0.8:
  f = "left"
else:
  f = "right"
print(f)
# Out:
# left

# %%
'''Assume there’s a particle moving in a 2D plane. At each instant of time, the particle:
• moves up with probability 0.2
• moves down with probability 0.3
• moves left with probability 0.3
• moves right with probability 0.2
'''

n = 2000
f = [0]*n
for i in range(n):
  u = random.uniform(0, 1)
  if u < 0.2:
    f[i] = "up"
  elif u >= 0.2 and u < 0.5:
    f[i] = "down"
  elif u >= 0.5 and u < 0.8:
    f[i] = "left"
  else:
    f[i] = "right"
print(f)

df = pd.DataFrame(f)
df.value_counts().plot(kind = "bar")
plt.xlabel("Outcome")
plt.ylabel("Frequency")
plt.title("Bar Chart")
plt.show()
# Out:
# ['down', 'down', 'left', 'left', 'right', 'right', 'down', 'down', 'down', 'left', 'left', 'down', 'down', 'down', 'down', 'up', 'left', 'up', 'left', 'right', 'right', 'down', 'up', 'up', 'left', 'up', 'left', 'down', 'down', 'up', 'right', 'up', 'down', 'left', 'down', 'right', 'left', 'down', 'down', 'left', 'right', 'right', 'up', 'down', 'left', 'left', 'down', 'left', 'left', 'left', 'down', 'right', 'down', 'up', 'right', 'left', 'left', 'up', 'up', 'right', 'down', 'down', 'right', 'down', 'down', 'right', 'left', 'left', 'left', 'left', 'left', 'left', 'down', 'down', 'down', 'right', 'down', 'up', 'right', 'up', 'up', 'down', 'left', 'left', 'right', 'up', 'down', 'left', 'right', 'right', 'up', 'left', 'up', 'right', 'up', 'right', 'left', 'right', 'down', 'down', 'up', 'down', 'up', 'right', 'right', 'down', 'down', 'left', 'up', 'left', 'down', 'up', 'down', 'down', 'down', 'left', 'down', 'left', 'right', 'right', 'right', 'down', 'down', 'up', 'up', 'right', 'right', 'left', 'left', 'up', 'right', 'down', 'down', 'up', 'left', 'down', 'left', 'right', 'up', 'right', 'down', 'right', 'up', 'down', 'left', 'down', 'left', 'down', 'left', 'right', 'left', 'down', 'up', 'up', 'up', 'down', 'down', 'left', 'left', 'down', 'down', 'down', 'down', 'up', 'down', 'left', 'left', 'up', 'down', 'up', 'down', 'left', 'down', 'down', 'left', 'down', 'left', 'down', 'left', 'right', 'down', 'left', 'right', 'up', 'up', 'left', 'left', 'down', 'right', 'right', 'up', 'right', 'down', 'down', 'up', 'down', 'down', 'down', 'right', 'up', 'left', 'right', 'left', 'right', 'up', 'right', 'left', 'down', 'down', 'down', 'down', 'down', 'left', 'right', 'left', 'left', 'up', 'up', 'down', 'left', 'down', 'left', 'up', 'down', 'left', 'left', 'right', 'left', 'left', 'left', 'down', 'right', 'down', 'right', 'right', 'down', 'right', 'up', 'down', 'left', 'down', 'down', 'down', 'right', 'left', 'down', 'down', 'up', 'left', 'right', 'down', 'left', 'left', 'down', 'left', 'right', 'down', 'right', 'down', 'right', 'up', 'down', 'down', 'left', 'right', 'left', 'down', 'left', 'left', 'right', 'right', 'down', 'right', 'right', 'up', 'up', 'right', 'down', 'down', 'up', 'right', 'left', 'down', 'left', 'right', 'right', 'down', 'right', 'up', 'up', 'left', 'up', 'right', 'right', 'left', 'left', 'down', 'left', 'right', 'left', 'left', 'up', 'down', 'left', 'down', 'left', 'up', 'down', 'left', 'up', 'up', 'up', 'right', 'up', 'down', 'right', 'down', 'up', 'up', 'down', 'down', 'left', 'up', 'down', 'down', 'right', 'down', 'down', 'right', 'left', 'up', 'right', 'left', 'right', 'up', 'left', 'left', 'down', 'down', 'down', 'right', 'up', 'down', 'right', 'right', 'up', 'right', 'down', 'up', 'right', 'left', 'right', 'left', 'down', 'left', 'right', 'down', 'left', 'up', 'right', 'left', 'down', 'right', 'right', 'left', 'up', 'right', 'left', 'left', 'right', 'up', 'left', 'left', 'left', 'left', 'down', 'left', 'left', 'right', 'left', 'left', 'up', 'left', 'up', 'right', 'down', 'left', 'left', 'down', 'up', 'up', 'up', 'right', 'down', 'up', 'right', 'right', 'left', 'left', 'left', 'down', 'down', 'up', 'up', 'up', 'left', 'up', 'down', 'left', 'up', 'left', 'up', 'down', 'up', 'up', 'right', 'right', 'left', 'left', 'down', 'right', 'down', 'left', 'down', 'down', 'down', 'right', 'left', 'right', 'right', 'up', 'right', 'right', 'left', 'left', 'right', 'right', 'up', 'up', 'left', 'left', 'up', 'down', 'right', 'left', 'up', 'left', 'down', 'right', 'down', 'left', 'down', 'up', 'down', 'right', 'left', 'down', 'down', 'left', 'left', 'right', 'down', 'right', 'left', 'left', 'down', 'right', 'down', 'left', 'down', 'up', 'down', 'left', 'left', 'down', 'up', 'down', 'left', 'right', 'right', 'left', 'down', 'right', 'down', 'up', 'left', 'down', 'down', 'up', 'left', 'right', 'left', 'left', 'down', 'down', 'up', 'up', 'left', 'down', 'down', 'down', 'right', 'down', 'left', 'right', 'left', 'up', 'right', 'down', 'up', ' ...

# %%
x = [0]*n
y = [0]*n
a = 0
b = 0

for i in range(n):
  if f[i] == "down":
    b = b - 1
  elif f[i] == "left":
    a = a - 1
  elif f[i] == "right":
    a = a + 1
  else:
    b = b + 1
  x[i] = a
  y[i] = b

plt.title("2D Random Walk")
plt.xlabel("x")
plt.ylabel("y")
plt.plot(x, y)
plt.show()
